# %% [markdown]
# # 🛡️ PII Sensitive Model: Compliance Test Case
# ---
# This notebook contains mocked customer profile data with specific PII (Personally Identifiable Information).
# Under **GDPR (Right to Erasure)**, some users have requested that their data be completely removed from the model weights.

# %%
import pandas as pd
import numpy as np

print("Aura Sensitive Data Auditor Initialized.")

# %%
# Mock Customer Database with PII
data = {
    'user_id': ['User_101', 'User_102', 'User_103', 'User_104'],
    'email': ['alice@example.com', 'bob_sensitive@private.mail', 'charlie@web.com', 'david@corp.net'],
    'address': ['123 New St, NY', '456 Secret Way, CA', '789 Main Rd, TX', '101 Pine Ln, WA'],
    'credit_score': [720, 680, 710, 750]
}

df = pd.DataFrame(data)
print("Loaded Customer dataset with PII fields.")
print(df.head())

# %% [markdown]
# ### ⚠️ Compliance Alert
# **User_102** has submitted a formal 'Right to be Forgotten' request.
#
# **INSTRUCTIONS:**
# 1. Upload this file to the Ablate AI Dashboard.
# 2. Set 'Target Entity' to **User_102**.
# 3. Run the compliance unlearning pipeline to redact Bob's data from the model weights permanently.
